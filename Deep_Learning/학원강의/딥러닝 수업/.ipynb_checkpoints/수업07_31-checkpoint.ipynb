# %%
import tensorflow as tf

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
# 이미지 형태로 reshape 
X_train = X_train.reshape(-1, 28, 28, 1)  # gray scale image 
X_test = X_test.reshape(-1, 28, 28, 1)

print(X_train.shape, X_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15, 15))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(X_train[i].reshape(28,28))
    
plt.show()

# %%
model = tf.keras.Sequential([
    
    tf.keras.layers.Conv2D(32, (3,3), input_shape=(28,28,1)),
    tf.keras.layers.MaxPool2D(strides = (2,2)),

    tf.keras.layers.Conv2D(64, (3,3)),
    tf.keras.layers.MaxPool2D(strides = (2,2)),
    
    tf.keras.layers.Conv2D(128, (3,3)),
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(128, activation = 'relu' ),
    tf.keras.layers.Dense(10, activation = 'sigmoid' )
    
])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_64 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 3, 3, 128)         73856
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               147584
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
             loss='sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train,
                    epochs=20,
                    validation_split=0.2
                    )
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 67s 1ms/sample - loss: 0.4027 - accuracy: 0.8501 - val_loss: 0.3494 - val_accuracy: 0.8727
# Epoch 2/20
# 48000/48000 [==============================] - 82s 2ms/sample - loss: 0.3231 - accuracy: 0.8818 - val_loss: 0.3295 - val_accuracy: 0.8799
# Epoch 3/20
# 48000/48000 [==============================] - 76s 2ms/sample - loss: 0.2830 - accuracy: 0.8954 - val_loss: 0.2968 - val_accuracy: 0.8937
# Epoch 4/20
# 19904/48000 [===========>..................] - ETA: 36s - loss: 0.2503 - accuracy: 0.9067
