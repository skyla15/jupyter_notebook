# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. 데이터 셀렉션 및 필터링

# %%
titanic = pd.read_csv('../pandas_data/titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###### Bollean Filtering (1)

# %%
titanic.Pclass == 3
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
titanic[titanic.Pclass == 3].head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %% [markdown]
# ###### 조건에 맞게 데이터 선택하기

# %%
titanic.loc[( titanic['Sex'] == 'male') & (titanic['Pclass'] >= 1) & (titanic['Age'] >= 20)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # 정렬, Aggregation, Groupby
# - df.agg('mean', 'min', 'max', 'median', 'std')

# %%
titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic.agg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-61e44898cf0f> in <module>
# ----> 1 titanic.agg()
#
# TypeError: aggregate() missing 1 required positional argument: 'func'

# %%
titanic.agg(['mean', 'min', 'max', 'median', 'std'])
# Out:
#         PassengerId  Survived    Pclass                         Name     Sex  \
# mean     446.000000  0.383838  2.308642                          NaN     NaN
# min        1.000000  0.000000  1.000000          Abbing, Mr. Anthony  female
# max      891.000000  1.000000  3.000000  van Melkebeke, Mr. Philemon    male
# median   446.000000  0.000000  3.000000                          NaN     NaN
# std      257.353842  0.486592  0.836071                          NaN     NaN
#
#               Age     SibSp     Parch     Ticket        Fare
# mean    29.699118  0.523008  0.381594        NaN   32.204208
# min      0.420000  0.000000  0.000000     110152    0.000000
# max     80.000000  8.000000  6.000000  WE/P 5735  512.329200
# median  28.000000  0.000000  0.000000        NaN   14.454200
# std     14.526497  1.102743  0.806057        NaN   49.693429

# %% [markdown]
# # Unit Conversion

# %% [markdown]
# # 결측치 처리 - 데이터프레임객체['컬럼'].replace('변환문자', '기존문자열')

# %% [markdown]
# # 형변환
# - 컬럼명.astype('category')
#     라는 것도 있음
# - 연도 : 범주형

# %%
import numpy as np
import pandas as pd 

mpg = pd.read_csv('../pandas_data/auto-mpg.csv')

mpg
# Out:
#      18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0    15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1    18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2    16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3    17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4    15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500
# ..    ... ..    ...    ...     ...   ...  .. ..                       ...
# 392  27.0  4  140.0  86.00  2790.0  15.6  82  1           ford mustang gl
# 393  44.0  4   97.0  52.00  2130.0  24.6  82  2                 vw pickup
# 394  32.0  4  135.0  84.00  2295.0  11.6  82  1             dodge rampage
# 395  28.0  4  120.0  79.00  2625.0  18.6  82  1               ford ranger
# 396  31.0  4  119.0  82.00  2720.0  19.4  82  1                chevy s-10
#
# [397 rows x 9 columns]
